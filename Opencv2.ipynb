# %%
import cv2
import imutils

# %%
import numpy as np

# %%
image=cv2.imread("D:/Udemy/original/Master OpenCV/images/IMG_8295.jpg")

# %%
kernel1=np.ones((3,3),np.uint8)/8

# %%
import scipy
from scipy import signal

# %%
image
# Out:
# array([[[255, 255, 240],
#         [255, 255, 240],
#         [255, 255, 240],
#         ...,
#         [255, 255, 241],
#         [255, 255, 240],
#         [255, 255, 239]],
#
#        [[255, 255, 240],
#         [255, 255, 240],
#         [255, 255, 240],
#         ...,
#         [255, 255, 241],
#         [255, 255, 241],
#         [255, 255, 241]],
#
#        [[255, 255, 240],
#         [255, 255, 240],
#         [255, 255, 240],
#         ...,
#         [255, 255, 241],
#         [255, 255, 242],
#         [255, 255, 242]],
#
#        ...,
#
#        [[149, 181, 210],
#         [140, 174, 203],
#         [138, 174, 204],
#         ...,
#         [  2,  10,  27],
#         [  1,   9,  26],
#         [  1,   9,  26]],
#
#        [[147, 179, 208],
#         [140, 174, 203],
#         [135, 172, 200],
#         ...,
#         [  0,  10,  27],
#         [  0,  10,  27],
#         [  0,   9,  26]],
#
#        [[149, 181, 210],
#         [146, 178, 207],
#         [136, 173, 201],
# ...

# %%
import matplotlib.image as mpig
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image2=mpig.imread("D:/Udemy/original/Master OpenCV/images/IMG_8295.jpg")

# %%
plt.imshow(image2)

# %%
image.shape
# Out:
# (3456, 5184, 3)

# %%
height=(int)(3456*0.2)
width=(int)(5184*0.2)
dim=(width,height)

# %%
resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)

# %%
cv2.imshow("resized",resized)
cv2.waitKey(0)
# Out:
# 106

# %%
convolve=cv2.filter2D(resized,-1,kernel1)

# %%
cv2.imshow("con1",convolve)
cv2.waitKey(0)
# Out:
# 32

# %%
kernel2=np.ones((7,7),np.float32)/49

# %%
convolve2=cv2.filter2D(resized,-1,kernel2)

# %%
cv2.imshow("con2",convolve2)
cv2.waitKey(0)
# Out:
# 106
